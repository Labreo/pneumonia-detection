# %%
import pickle
import matplotlib.pyplot as plt

# Load the saved history data from the file
with open('training_history.pkl', 'rb') as file_pi:
    history = pickle.load(file_pi)

# Create a figure to hold the plots
plt.figure(figsize=(14, 5))

# --- Plot 1: Model Accuracy ---
plt.subplot(1, 2, 1) # 1 row, 2 columns, plot 1
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('📈 Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# --- Plot 2: Model Loss ---
plt.subplot(1, 2, 2) # 1 row, 2 columns, plot 2
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('📉 Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# Show the plots
plt.tight_layout() # Adjusts plot parameters for a tight layout
plt.show()
# Out:
# /var/folders/rr/7rsm0nxj31ndgrk8ntc261k00000gn/T/ipykernel_33581/831236783.py:30: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout() # Adjusts plot parameters for a tight layout
# /var/folders/rr/7rsm0nxj31ndgrk8ntc261k00000gn/T/ipykernel_33581/831236783.py:30: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout() # Adjusts plot parameters for a tight layout
# /Users/sanjaywaradkar/miniforge3/envs/myenv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sanjaywaradkar/miniforge3/envs/myenv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
